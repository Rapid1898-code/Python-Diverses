# %%
import pandas as pd
import numpy as np
df = pd.read_excel ("C:\TEMP\COVID-19-geographic-disbtribution-worldwide (1).xlsx")
pd.set_option ("display.max_columns", 100)  # dadurch werden alle Spalten ausgegeben
pd.set_option ("display.max_rows", 100)  # dadurch werden alle Zeilen ausgegeben

# %%
# Zeilenanzahl, Spaltenanzahl
df.shape
# Out:
# (13211, 11)

# %%
# Infos zu Spalten
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13211 entries, 0 to 13210
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  13211 non-null  datetime64[ns]
#  1   day                      13211 non-null  int64
#  2   month                    13211 non-null  int64
#  3   year                     13211 non-null  int64
#  4   cases                    13211 non-null  int64
#  5   deaths                   13211 non-null  int64
#  6   countriesAndTerritories  13211 non-null  object
#  7   geoId                    13168 non-null  object
#  8   countryterritoryCode     13067 non-null  object
#  9   popData2018              13095 non-null  float64
#  10  continentExp             13211 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 1.1+ MB

# %%
# Ausgabe der ersten 5 Zeilen
df.head(5)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-04-26   26      4  2020    112       4             Afghanistan    AF
# 1 2020-04-25   25      4  2020     70       1             Afghanistan    AF
# 2 2020-04-24   24      4  2020    105       2             Afghanistan    AF
# 3 2020-04-23   23      4  2020     84       4             Afghanistan    AF
# 4 2020-04-22   22      4  2020     61       1             Afghanistan    AF
#
#   countryterritoryCode  popData2018 continentExp
# 0                  AFG   37172386.0         Asia
# 1                  AFG   37172386.0         Asia
# 2                  AFG   37172386.0         Asia
# 3                  AFG   37172386.0         Asia
# 4                  AFG   37172386.0         Asia

# %%
# Ausgbe der letzten 5 Zeilen
df.tail(5)
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 13206 2020-03-25   25      3  2020      0       0                Zimbabwe
# 13207 2020-03-24   24      3  2020      0       1                Zimbabwe
# 13208 2020-03-23   23      3  2020      0       0                Zimbabwe
# 13209 2020-03-22   22      3  2020      1       0                Zimbabwe
# 13210 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018 continentExp
# 13206    ZW                  ZWE   14439018.0       Africa
# 13207    ZW                  ZWE   14439018.0       Africa
# 13208    ZW                  ZWE   14439018.0       Africa
# 13209    ZW                  ZWE   14439018.0       Africa
# 13210    ZW                  ZWE   14439018.0       Africa

# %%
#  Ausgabe einer bestimmten Spalte (2 verschiedene Möglichkeiten)
df["countriesAndTerritories"]
df.countriesAndTerritories[0:5]
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: countriesAndTerritories, dtype: object

# %%
# Wenn nur eine Spalte ausgewählt ist, handelt es sich um eine Serie  
type(df["countriesAndTerritories"])
# Out:
# pandas.core.series.Series

# %%
df[["countriesAndTerritories","geoId"]][0:5]
# Out:
#   countriesAndTerritories geoId
# 0             Afghanistan    AF
# 1             Afghanistan    AF
# 2             Afghanistan    AF
# 3             Afghanistan    AF
# 4             Afghanistan    AF

# %%
# Ausgabe der Spaltennamen
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2018', 'continentExp'],
#       dtype='object')

# %%
# Ausgabe der Anzahl der Werte in einer Spalte
df.countriesAndTerritories.value_counts()
# Out:
# Italy                          118
# United_States_of_America       118
# Iceland                        118
# Netherlands                    118
# France                         118
#                               ...
# Falkland_Islands_(Malvinas)     23
# South_Sudan                     21
# Sao_Tome_and_Principe           18
# Yemen                           17
# Western_Sahara                   1
# Name: countriesAndTerritories, Length: 207, dtype: int64

# %%
# Outputs the First Row
df.iloc[0]
# Out:
# dateRep                    2020-04-26 00:00:00
# day                                         26
# month                                        4
# year                                      2020
# cases                                      112
# deaths                                       4
# countriesAndTerritories            Afghanistan
# geoId                                       AF
# countryterritoryCode                       AFG
# popData2018                        3.71724e+07
# continentExp                              Asia
# Name: 0, dtype: object

# %%
# Ausgabe der ersten beiden Zeilen
df.iloc[[0,1]]
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-04-26   26      4  2020    112       4             Afghanistan    AF
# 1 2020-04-25   25      4  2020     70       1             Afghanistan    AF
#
#   countryterritoryCode  popData2018 continentExp
# 0                  AFG   37172386.0         Asia
# 1                  AFG   37172386.0         Asia

# %%
# Ausgabe der ersten Spalte für die ersten beiden Zeilen
df.iloc[[0,1],0]
# Out:
# 0   2020-04-26
# 1   2020-04-25
# Name: dateRep, dtype: datetime64[ns]

# %%
# Ausgabe der ersten beiden Zeilen - mit den Spalten 6+7
df.iloc[[0,1],[5,6]]
# Out:
#    deaths countriesAndTerritories
# 0       4             Afghanistan
# 1       1             Afghanistan

# %%
# Ausgabe der Spalten day + month für die ersten beiden Zeilen
df.loc[[0,1],["day","month"]]
# Out:
#    day  month
# 0   26      4
# 1   25      4

# %%
# Ausgabe der ersten 10 Zeilen für die Spalten day+month
df.loc[0:10,["day","month"]][0:5]
# Out:
#    day  month
# 0   26      4
# 1   25      4
# 2   24      4
# 3   23      4
# 4   22      4

# %%
# Ausgabe der ersten 10 Zeilen für die Spalten von day bis deaths
df.loc[0:10,"day":"deaths"][0:5]
# Out:
#    day  month  year  cases  deaths
# 0   26      4  2020    112       4
# 1   25      4  2020     70       1
# 2   24      4  2020    105       2
# 3   23      4  2020     84       4
# 4   22      4  2020     61       1

# %%
# Setzt Index auf eine bestimmte Spalte (ohne inplace wird es nicht angewandt - nur ausprobiert)
df.set_index("countriesAndTerritories", inplace=True)
df[0:5]
# Out:
#                            dateRep  day  month  year  cases  deaths geoId  \
# countriesAndTerritories
# Afghanistan             2020-04-26   26      4  2020    112       4    AF
# Afghanistan             2020-04-25   25      4  2020     70       1    AF
# Afghanistan             2020-04-24   24      4  2020    105       2    AF
# Afghanistan             2020-04-23   23      4  2020     84       4    AF
# Afghanistan             2020-04-22   22      4  2020     61       1    AF
#
#                         countryterritoryCode  popData2018 continentExp
# countriesAndTerritories
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia

# %%
# Abfrage auf den zuvor definierten Index
df.loc["Germany"][0:5]
# Out:
#                            dateRep  day  month  year  cases  deaths geoId  \
# countriesAndTerritories
# Germany                 2020-04-26   26      4  2020   1737     140    DE
# Germany                 2020-04-25   25      4  2020   2055     179    DE
# Germany                 2020-04-24   24      4  2020   2337     227    DE
# Germany                 2020-04-23   23      4  2020   2352     215    DE
# Germany                 2020-04-22   22      4  2020   2237     281    DE
#
#                         countryterritoryCode  popData2018 continentExp
# countriesAndTerritories
# Germany                                  DEU   82927922.0       Europe
# Germany                                  DEU   82927922.0       Europe
# Germany                                  DEU   82927922.0       Europe
# Germany                                  DEU   82927922.0       Europe
# Germany                                  DEU   82927922.0       Europe

# %%
# Absteigende Sortierung nach Index
df.sort_index(ascending=False, inplace=True)
df[0:5]
# Out:
#                            dateRep  day  month  year  cases  deaths geoId  \
# countriesAndTerritories
# Zimbabwe                2020-03-21   21      3  2020      1       0    ZW
# Zimbabwe                2020-04-18   18      4  2020      0       0    ZW
# Zimbabwe                2020-04-10   10      4  2020      0       1    ZW
# Zimbabwe                2020-04-11   11      4  2020      0       0    ZW
# Zimbabwe                2020-04-12   12      4  2020      3       0    ZW
#
#                         countryterritoryCode  popData2018 continentExp
# countriesAndTerritories
# Zimbabwe                                 ZWE   14439018.0       Africa
# Zimbabwe                                 ZWE   14439018.0       Africa
# Zimbabwe                                 ZWE   14439018.0       Africa
# Zimbabwe                                 ZWE   14439018.0       Africa
# Zimbabwe                                 ZWE   14439018.0       Africa

# %%
# Aufsteigende Sortierung nach Index
df.sort_index(inplace=True)
df[0:5]
# Out:
#                            dateRep  day  month  year  cases  deaths geoId  \
# countriesAndTerritories
# Afghanistan             2020-04-26   26      4  2020    112       4    AF
# Afghanistan             2020-04-01    1      4  2020     25       0    AF
# Afghanistan             2020-02-22   22      2  2020      0       0    AF
# Afghanistan             2020-04-24   24      4  2020    105       2    AF
# Afghanistan             2020-04-23   23      4  2020     84       4    AF
#
#                         countryterritoryCode  popData2018 continentExp
# countriesAndTerritories
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia
# Afghanistan                              AFG   37172386.0         Asia

# %%
# Index wird wieder zurückgesetzt
df.reset_index(inplace=True)
df[0:5]
# Out:
#   countriesAndTerritories    dateRep  day  month  year  cases  deaths geoId  \
# 0             Afghanistan 2020-04-26   26      4  2020    112       4    AF
# 1             Afghanistan 2020-04-01    1      4  2020     25       0    AF
# 2             Afghanistan 2020-02-22   22      2  2020      0       0    AF
# 3             Afghanistan 2020-04-24   24      4  2020    105       2    AF
# 4             Afghanistan 2020-04-23   23      4  2020     84       4    AF
#
#   countryterritoryCode  popData2018 continentExp
# 0                  AFG   37172386.0         Asia
# 1                  AFG   37172386.0         Asia
# 2                  AFG   37172386.0         Asia
# 3                  AFG   37172386.0         Asia
# 4                  AFG   37172386.0         Asia

# %%
# Filterung auf den Wert einer Spalte
filt = (df["countriesAndTerritories"] == "Austria")
df[filt][0:5]
# Out:
#     countriesAndTerritories    dateRep  day  month  year  cases  deaths geoId  \
# 732                 Austria 2020-04-21   21      4  2020     73      10    AT
# 733                 Austria 2020-04-18   18      4  2020    155      21    AT
# 734                 Austria 2020-04-19   19      4  2020     59      12    AT
# 735                 Austria 2020-04-20   20      4  2020     48       9    AT
# 736                 Austria 2020-04-22   22      4  2020     50       1    AT
#
#     countryterritoryCode  popData2018 continentExp
# 732                  AUT    8847037.0       Europe
# 733                  AUT    8847037.0       Europe
# 734                  AUT    8847037.0       Europe
# 735                  AUT    8847037.0       Europe
# 736                  AUT    8847037.0       Europe

# %%
# Anwendung des Filters mit Ausgabew nur einer Spalte
df.loc[filt, "deaths"][0:5]
# Out:
# 732    10
# 733    21
# 734    12
# 735     9
# 736     1
# Name: deaths, dtype: int64

# %%
# Filterung nach den 2 Ländern Austria und Germany
filt2 = (df["countriesAndTerritories"] == "Austria") | (df["countriesAndTerritories"] == "Germany")
df.loc[filt2][0:5]
# Out:
#     countriesAndTerritories    dateRep  day  month  year  cases  deaths geoId  \
# 732                 Austria 2020-04-21   21      4  2020     73      10    AT
# 733                 Austria 2020-04-18   18      4  2020    155      21    AT
# 734                 Austria 2020-04-19   19      4  2020     59      12    AT
# 735                 Austria 2020-04-20   20      4  2020     48       9    AT
# 736                 Austria 2020-04-22   22      4  2020     50       1    AT
#
#     countryterritoryCode  popData2018 continentExp
# 732                  AUT    8847037.0       Europe
# 733                  AUT    8847037.0       Europe
# 734                  AUT    8847037.0       Europe
# 735                  AUT    8847037.0       Europe
# 736                  AUT    8847037.0       Europe

# %%
# Filterung auf mehr als 100 Tote pro Tag mit Ausgabe von bestimmten Spalten

high_deaths = (df["deaths"] > 100)
df.loc[high_deaths, ["dateRep","countriesAndTerritories","deaths"]][0:5]
# Out:
#         dateRep countriesAndTerritories  deaths
# 1311 2020-04-20                 Belgium     230
# 1312 2020-04-18                 Belgium     306
# 1313 2020-04-19                 Belgium     290
# 1314 2020-04-21                 Belgium     145
# 1315 2020-04-14                 Belgium     303

# %%
# Filterung auf mehrere Einträge aus einer Liste
countries =["Austria","Germany","Switzerland"]
filt3 = df["countriesAndTerritories"].isin(countries)
df[filt3][0:5]
# Out:
#     countriesAndTerritories    dateRep  day  month  year  cases  deaths geoId  \
# 732                 Austria 2020-04-21   21      4  2020     73      10    AT
# 733                 Austria 2020-04-18   18      4  2020    155      21    AT
# 734                 Austria 2020-04-19   19      4  2020     59      12    AT
# 735                 Austria 2020-04-20   20      4  2020     48       9    AT
# 736                 Austria 2020-04-22   22      4  2020     50       1    AT
#
#     countryterritoryCode  popData2018 continentExp
# 732                  AUT    8847037.0       Europe
# 733                  AUT    8847037.0       Europe
# 734                  AUT    8847037.0       Europe
# 735                  AUT    8847037.0       Europe
# 736                  AUT    8847037.0       Europe

# %%
# Änderung der Spaltenbezeichnung auf Großschreibung
df.columns = [x.upper() for x in df.columns]
df[0:2]
# Out:
#   COUNTRIESANDTERRITORIES    DATEREP  DAY  MONTH  YEAR  CASES  DEATHS GEOID  \
# 0             Afghanistan 2020-04-26   26      4  2020    112       4    AF
# 1             Afghanistan 2020-04-01    1      4  2020     25       0    AF
#
#   COUNTRYTERRITORYCODE  POPDATA2018 CONTINENTEXP
# 0                  AFG   37172386.0         Asia
# 1                  AFG   37172386.0         Asia

# %%
# Kleinschreibung der Überschrift und 2 Spalten umbenennen
df.columns = [x.lower() for x in df.columns]
df.rename(columns={"countriesandterritories":"land","continentexp":"continent"},inplace=True)
df[2:4]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 2  Afghanistan 2020-02-22   22      2  2020      0       0    AF
# 3  Afghanistan 2020-04-24   24      4  2020    105       2    AF
#
#   countryterritorycode  popdata2018 continent
# 2                  AFG   37172386.0      Asia
# 3                  AFG   37172386.0      Asia

# %%
# (1) Änderungen des Satzes mit Index=2 für land und year mit neuen Werten
# (2) Änderungen des Satzes mit Index=3 für continent
df.loc[2, ["land","year"]] = ["NewLand","2099"]
df.loc[3,"continent"] =  "NewCont"
df.loc[2:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 2      NewLand 2020-02-22   22      2  2099      0       0    AF
# 3  Afghanistan 2020-04-24   24      4  2020    105       2    AF
#
#   countryterritorycode  popdata2018 continent
# 2                  AFG   37172386.0      Asia
# 3                  AFG   37172386.0   NewCont

# %%
# Spalte geoid auf Kleinschreibung umstellen
df["geoid"] = df["geoid"].str.lower()
df.loc[2:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 2      NewLand 2020-02-22   22      2  2099      0       0    af
# 3  Afghanistan 2020-04-24   24      4  2020    105       2    af
#
#   countryterritorycode  popdata2018 continent
# 2                  AFG   37172386.0      Asia
# 3                  AFG   37172386.0   NewCont

# %%
df.columns
# Out:
# Index(['land', 'daterep', 'day', 'month', 'year', 'cases', 'deaths', 'geoid',
#        'countryterritorycode', 'popdata2018', 'continent'],
#       dtype='object')

# %%
# Apply - kann auf Dataframe und Series angewandt werden
# Verwendung einer Funktion für Elemente
df["countryterritorycode"][0:5].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: countryterritorycode, dtype: int64

# %%
# Definition einer eigenen Funktion die dann auf die Spalte continent angewandt und neu zugeordnet wird
def update_cont(continent):
    return continent.upper()
df["continent"] = df["continent"].apply(update_cont)
df[0:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 0  Afghanistan 2020-04-26   26      4  2020    112       4    af
# 1  Afghanistan 2020-04-01    1      4  2020     25       0    af
# 2      NewLand 2020-02-22   22      2  2099      0       0    af
#
#   countryterritorycode  popdata2018 continent
# 0                  AFG   37172386.0      ASIA
# 1                  AFG   37172386.0      ASIA
# 2                  AFG   37172386.0      ASIA

# %%
# Gleich Anwendung mit Lambda-Funktin - Spalte wird klein geschrieben
df["continent"] = df["continent"].apply(lambda x: x.lower())
df[0:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 0  Afghanistan 2020-04-26   26      4  2020    112       4    af
# 1  Afghanistan 2020-04-01    1      4  2020     25       0    af
# 2      NewLand 2020-02-22   22      2  2099      0       0    af
#
#   countryterritorycode  popdata2018 continent
# 0                  AFG   37172386.0      asia
# 1                  AFG   37172386.0      asia
# 2                  AFG   37172386.0      asia

# %%
# Anwendung von Apply auf ein ganzes Dataframe => Zählung der Anzahl pro Spalte
df.apply(len)[0:5]
# Out:
# land       13211
# daterep    13211
# day        13211
# month      13211
# year       13211
# dtype: int64

# %%
# Kann auch auf die Spalten angewandet werden - d.h. hier bekommt man die Anzahl der einzelnen Zeilen
df.apply(len, axis="columns")[0:3]
# Out:
# 0    11
# 1    11
# 2    11
# dtype: int64

# %%
df.columns
# Out:
# Index(['land', 'daterep', 'day', 'month', 'year', 'cases', 'deaths', 'geoid',
#        'countryterritorycode', 'popdata2018', 'continent'],
#       dtype='object')

# %%
# durch map erfolgt  Umbennenung der von Austria und Germany
# alle anderen Länder werden aber auf NaN geändert
df["countryterritorycode"].map({"Austria":"Österreich","Germany":"Deutschland"})
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 13206    NaN
# 13207    NaN
# 13208    NaN
# 13209    NaN
# 13210    NaN
# Name: countryterritorycode, Length: 13211, dtype: object

# %%
# mit replace werden die anderen Felder nicht angegriffen
df["countriesAndTerritories"] = df["land"].replace({"Austria":"Österreich","Germany":"Deutschland"})
df[0:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 0  Afghanistan 2020-04-26   26      4  2020    112       4    af
# 1  Afghanistan 2020-04-01    1      4  2020     25       0    af
# 2      NewLand 2020-02-22   22      2  2099      0       0    af
#
#   countryterritorycode  popdata2018 continent countriesAndTerritories
# 0                  AFG   37172386.0      asia             Afghanistan
# 1                  AFG   37172386.0      asia             Afghanistan
# 2                  AFG   37172386.0      asia                 NewLand

# %%
# Neu Spalte hinufügen am Ende des Dataframe
df["fullgeo"] = df["geoid"] + df["countryterritorycode"]
df[0:3]
# Out:
#           land    daterep  day  month  year  cases  deaths geoid  \
# 0  Afghanistan 2020-04-26   26      4  2020    112       4    af
# 1  Afghanistan 2020-04-01    1      4  2020     25       0    af
# 2      NewLand 2020-02-22   22      2  2099      0       0    af
#
#   countryterritorycode  popdata2018 continent countriesAndTerritories fullgeo
# 0                  AFG   37172386.0      asia             Afghanistan   afAFG
# 1                  AFG   37172386.0      asia             Afghanistan   afAFG
# 2                  AFG   37172386.0      asia                 NewLand   afAFG

# %%
# Löschen der beiden Spalten geoid und countryterritorycode
df.drop(columns=["geoid","countryterritorycode"], inplace=True)

# %%
df[0:3]
# Out:
#           land    daterep  day  month  year  cases  deaths  popdata2018  \
# 0  Afghanistan 2020-04-26   26      4  2020    112       4   37172386.0
# 1  Afghanistan 2020-04-01    1      4  2020     25       0   37172386.0
# 2      NewLand 2020-02-22   22      2  2099      0       0   37172386.0
#
#   continent countriesAndTerritories fullgeo
# 0      asia             Afghanistan   afAFG
# 1      asia             Afghanistan   afAFG
# 2      asia                 NewLand   afAFG

# %%
# Neuer Satz wird hinzugefügt
df.append({"land":"AAANeuesLand"},ignore_index=True).tail(3)
# Out:
#                land    daterep   day  month  year  cases  deaths  popdata2018  \
# 13209      Zimbabwe 2020-03-28  28.0    3.0  2020    2.0     0.0   14439018.0
# 13210      Zimbabwe 2020-03-21  21.0    3.0  2020    1.0     0.0   14439018.0
# 13211  AAANeuesLand        NaT   NaN    NaN   NaN    NaN     NaN          NaN
#
#       continent countriesAndTerritories fullgeo
# 13209    africa                Zimbabwe   zwZWE
# 13210    africa                Zimbabwe   zwZWE
# 13211       NaN                     NaN     NaN

# %%
# Zusammenfügen von 2 Dataframes - Index muss ignoriert werden
# df.append(df2, ignore_index=True)

# %%
# alle Zeilen mit land = Zimbabwe werden gelöscht
filt = df["land"] == "Zimbabwe"
df.drop(index=df[filt].index)[5:]
# Out:
#               land    daterep  day  month  year  cases  deaths  popdata2018  \
# 5      Afghanistan 2020-04-22   22      4  2020     61       1   37172386.0
# 6      Afghanistan 2020-04-21   21      4  2020     35       2   37172386.0
# 7      Afghanistan 2020-04-20   20      4  2020     88       3   37172386.0
# 8      Afghanistan 2020-04-19   19      4  2020     63       0   37172386.0
# 9      Afghanistan 2020-04-18   18      4  2020     51       1   37172386.0
# ...            ...        ...  ...    ...   ...    ...     ...          ...
# 13169       Zambia 2020-03-20   20      3  2020      0       0   17351822.0
# 13170       Zambia 2020-04-05    5      4  2020      0       0   17351822.0
# 13171       Zambia 2020-03-19   19      3  2020      2       0   17351822.0
# 13172       Zambia 2020-03-26   26      3  2020      9       0   17351822.0
# 13173       Zambia 2020-03-27   27      3  2020      2       0   17351822.0
#
#       continent countriesAndTerritories fullgeo
# 5          asia             Afghanistan   afAFG
# 6          asia             Afghanistan   afAFG
# 7          asia             Afghanistan   afAFG
# 8          asia             Afghanistan   afAFG
# 9          asia             Afghanistan   afAFG
# ...         ...                     ...     ...
# 13169    africa                  Zambia   zmZMB
# 13170    africa                  Zambia   zmZMB
# 13171    africa                  Zambia   zmZMB
# 13172    africa                  Zambia   zmZMB
# 13173    africa                  Zambia   zmZMB
#
# [13169 rows x 11 columns]

# %%
# Sortierung nach einer Spalte aufsteigend
df.sort_values(by="daterep")
# Out:
#               land    daterep  day  month  year  cases  deaths  popdata2018  \
# 3788         Egypt 2019-12-31   31     12  2019      0       0   98423595.0
# 1416       Belgium 2019-12-31   31     12  2019      0       0   11422068.0
# 4405        France 2019-12-31   31     12  2019      0       0   66987244.0
# 7707      Malaysia 2019-12-31   31     12  2019      0       0   31528585.0
# 9817   Philippines 2019-12-31   31     12  2019      0       0  106651922.0
# ...            ...        ...  ...    ...   ...    ...     ...          ...
# 6691        Jordan 2020-04-26   26      4  2020      3       0    9956011.0
# 12374       Uganda 2020-04-26   26      4  2020      0       0   42723139.0
# 8627   Netherlands 2020-04-26   26      4  2020    655     120   17231017.0
# 1735        Brazil 2020-04-26   26      4  2020   5514     346  209469333.0
# 0      Afghanistan 2020-04-26   26      4  2020    112       4   37172386.0
#
#       continent countriesAndTerritories fullgeo
# 3788     africa                   Egypt   egEGY
# 1416     europe                 Belgium   beBEL
# 4405     europe                  France   frFRA
# 7707       asia                Malaysia   myMYS
# 9817       asia             Philippines   phPHL
# ...         ...                     ...     ...
# 6691       asia                  Jordan   joJOR
# 12374    africa                  Uganda   ugUGA
# 8627     europe             Netherlands   nlNLD
# 1735    america                  Brazil   brBRA
# 0          asia             Afghanistan   afAFG
#
# [13211 rows x 11 columns]

# %%
# Sortierung nach einer Spalte absteigend
df.sort_values(by="daterep", ascending=False)
# Out:
#                                    land    daterep  day  month  year  cases  \
# 0                           Afghanistan 2020-04-26   26      4  2020    112
# 3244   Democratic_Republic_of_the_Congo 2020-04-26   26      4  2020     26
# 3732                              Egypt 2020-04-26   26      4  2020    227
# 10338                            Rwanda 2020-04-26   26      4  2020      7
# 10387             Saint_Kitts_and_Nevis 2020-04-26   26      4  2020      0
# ...                                 ...        ...  ...    ...   ...    ...
# 9016                            Nigeria 2019-12-31   31     12  2019      0
# 1089                            Bahrain 2019-12-31   31     12  2019      0
# 4987                             Greece 2019-12-31   31     12  2019      0
# 9102                    North_Macedonia 2019-12-31   31     12  2019      0
# 12821          United_States_of_America 2019-12-31   31     12  2019      0
#
#        deaths  popdata2018 continent           countriesAndTerritories fullgeo
# 0           4   37172386.0      asia                       Afghanistan   afAFG
# 3244        0   84068091.0    africa  Democratic_Republic_of_the_Congo   cdCOD
# 3732       13   98423595.0    africa                             Egypt   egEGY
# 10338       0   12301939.0    africa                            Rwanda   rwRWA
# 10387       0      52441.0   america             Saint_Kitts_and_Nevis   knKNA
# ...       ...          ...       ...                               ...     ...
# 9016        0  195874740.0    africa                           Nigeria   ngNGA
# 1089        0    1569439.0      asia                           Bahrain   bhBHR
# 4987        0   10727668.0    europe                            Greece   elGRC
# 9102        0    2082958.0    europe                   North_Macedonia   mkMKD
# 12821       0  327167434.0   america          United_States_of_America   usUSA
#
# [13211 rows x 11 columns]

# %%
# Sortierung nach 2 Argumenten absteigend - zuerst nach dateRep und dann nach cases
df.sort_values(by=["daterep","cases"], ascending=False)
# Out:
#                            land    daterep  day  month  year  cases  deaths  \
# 12780  United_States_of_America 2020-04-26   26      4  2020  48529    2172
# 10220                    Russia 2020-04-26   26      4  2020   5966      66
# 1735                     Brazil 2020-04-26   26      4  2020   5514     346
# 12572            United_Kingdom 2020-04-26   26      4  2020   4913     813
# 9692                       Peru 2020-04-26   26      4  2020   3683      66
# ...                         ...        ...  ...    ...   ...    ...     ...
# 12112                  Thailand 2019-12-31   31     12  2019      0       0
# 12553      United_Arab_Emirates 2019-12-31   31     12  2019      0       0
# 12654            United_Kingdom 2019-12-31   31     12  2019      0       0
# 12821  United_States_of_America 2019-12-31   31     12  2019      0       0
# 13089                   Vietnam 2019-12-31   31     12  2019      0       0
#
#        popdata2018 continent   countriesAndTerritories fullgeo
# 12780  327167434.0   america  United_States_of_America   usUSA
# 10220  144478050.0    europe                    Russia   ruRUS
# 1735   209469333.0   america                    Brazil   brBRA
# 12572   66488991.0    europe            United_Kingdom   ukGBR
# 9692    31989256.0   america                      Peru   pePER
# ...            ...       ...                       ...     ...
# 12112   69428524.0      asia                  Thailand   thTHA
# 12553    9630959.0      asia      United_Arab_Emirates   aeARE
# 12654   66488991.0    europe            United_Kingdom   ukGBR
# 12821  327167434.0   america  United_States_of_America   usUSA
# 13089   95540395.0      asia                   Vietnam   vnVNM
#
# [13211 rows x 11 columns]

# %%
# Sortierung nach 2 Argumenten absteigend - zuerst nach dateRep und dann nach cases - 
# aber der erste Wert absteigend und der zweite aufsteigend
# durch inplace = True erfolgt die Sortierung dauerhaft im Dataframe
df.sort_values(by=["daterep","cases"], ascending=[False,True], inplace=True)

# %%
# Sortierung wird wieder rückgängig gemacht (indem Sortierung nach dem Index erfolgt)
df.sort_index()
# Out:
#               land    daterep  day  month  year  cases  deaths  popdata2018  \
# 0      Afghanistan 2020-04-26   26      4  2020    112       4   37172386.0
# 1      Afghanistan 2020-04-01    1      4  2020     25       0   37172386.0
# 2          NewLand 2020-02-22   22      2  2099      0       0   37172386.0
# 3      Afghanistan 2020-04-24   24      4  2020    105       2   37172386.0
# 4      Afghanistan 2020-04-23   23      4  2020     84       4   37172386.0
# ...            ...        ...  ...    ...   ...    ...     ...          ...
# 13206     Zimbabwe 2020-04-06    6      4  2020      0       0   14439018.0
# 13207     Zimbabwe 2020-03-29   29      3  2020      2       0   14439018.0
# 13208     Zimbabwe 2020-04-07    7      4  2020      0       0   14439018.0
# 13209     Zimbabwe 2020-03-28   28      3  2020      2       0   14439018.0
# 13210     Zimbabwe 2020-03-21   21      3  2020      1       0   14439018.0
#
#       continent countriesAndTerritories fullgeo
# 0          asia             Afghanistan   afAFG
# 1          asia             Afghanistan   afAFG
# 2          asia                 NewLand   afAFG
# 3       newcont             Afghanistan   afAFG
# 4          asia             Afghanistan   afAFG
# ...         ...                     ...     ...
# 13206    africa                Zimbabwe   zwZWE
# 13207    africa                Zimbabwe   zwZWE
# 13208    africa                Zimbabwe   zwZWE
# 13209    africa                Zimbabwe   zwZWE
# 13210    africa                Zimbabwe   zwZWE
#
# [13211 rows x 11 columns]

# %%
# Es können auch einzelne Series sortiert werden - und nicht das ganze Dataframe
# Hier die Spalte Land absteigend
df["land"].sort_values(ascending=False)
# Out:
# 13198       Zimbabwe
# 13209       Zimbabwe
# 13190       Zimbabwe
# 13195       Zimbabwe
# 13177       Zimbabwe
#             ...
# 58       Afghanistan
# 80       Afghanistan
# 0        Afghanistan
# 104      Afghanistan
# 55       Afghanistan
# Name: land, Length: 13211, dtype: object

# %%
# Ausgabe der 5 höchsten Werte in der deaths Spalte
df["deaths"].nlargest(5)
# Out:
# 12772    4928
# 12759    3770
# 12778    3179
# 12770    2524
# 12771    2408
# Name: deaths, dtype: int64

# %%
# Ausgabe der 5 höchsten Werte in der death Spalte - aber mit allen Werten
df.nlargest(5, "deaths")
# Out:
#                            land    daterep  day  month  year  cases  deaths  \
# 12772  United_States_of_America 2020-04-16   16      4  2020  30148    4928
# 12759  United_States_of_America 2020-04-18   18      4  2020  30833    3770
# 12778  United_States_of_America 2020-04-24   24      4  2020  26543    3179
# 12770  United_States_of_America 2020-04-22   22      4  2020  37289    2524
# 12771  United_States_of_America 2020-04-15   15      4  2020  26922    2408
#
#        popdata2018 continent   countriesAndTerritories fullgeo
# 12772  327167434.0   america  United_States_of_America   usUSA
# 12759  327167434.0   america  United_States_of_America   usUSA
# 12778  327167434.0   america  United_States_of_America   usUSA
# 12770  327167434.0   america  United_States_of_America   usUSA
# 12771  327167434.0   america  United_States_of_America   usUSA

# %%
# Ausgabe der 5 kleinsten Werte in der popdata2018 Spalte
df.nsmallest(5, "popdata2018")
# Out:
#           land    daterep  day  month  year  cases  deaths  popdata2018  \
# 5386  Holy_See 2020-04-26   26      4  2020      0       0       1000.0
# 5371  Holy_See 2020-04-25   25      4  2020      0       0       1000.0
# 5370  Holy_See 2020-04-24   24      4  2020      0       0       1000.0
# 5372  Holy_See 2020-04-23   23      4  2020      0       0       1000.0
# 5387  Holy_See 2020-04-22   22      4  2020      0       0       1000.0
#
#      continent countriesAndTerritories fullgeo
# 5386    europe                Holy_See   vaVAT
# 5371    europe                Holy_See   vaVAT
# 5370    europe                Holy_See   vaVAT
# 5372    europe                Holy_See   vaVAT
# 5387    europe                Holy_See   vaVAT

# %%
# Medianwert für die Spalte popdata2018
df["popdata2018"].median()
# Out:
# 9956011.0

# %%
# Medianwert für alle (möglichen) Werte bzw. welche float64 sind
df.median()
# Out:
# day                 17.0
# month                3.0
# year              2020.0
# cases                1.0
# deaths               0.0
# popdata2018    9956011.0
# dtype: float64

# %%
# Ausgabe verschiedener statistischer Werte für den ganzen Dataframe
df.describe()
# Out:
#                 day         month         cases        deaths   popdata2018
# count  13211.000000  13211.000000  13211.000000  13211.000000  1.309500e+04
# mean      16.089017      2.985315    215.329044     15.238438  5.655837e+07
# std        8.504544      1.260089   1542.577168    119.311467  1.864375e+08
# min        1.000000      1.000000     -9.000000      0.000000  1.000000e+03
# 25%        9.000000      2.000000      0.000000      0.000000  2.789533e+06
# 50%       17.000000      3.000000      1.000000      0.000000  9.956011e+06
# 75%       23.000000      4.000000     26.000000      0.000000  3.797855e+07
# max       31.000000     12.000000  48529.000000   4928.000000  1.392730e+09

# %%
# Anzahl der Sätze pro Land
df["land"].value_counts()
# Out:
# China                    118
# Czechia                  118
# Australia                118
# Russia                   118
# Iran                     118
#                         ...
# South_Sudan               21
# Sao_Tome_and_Principe     18
# Yemen                     17
# Western_Sahara             1
# NewLand                    1
# Name: land, Length: 208, dtype: int64

# %%
# Ausgabe von vbalue_counts in Prozentwerte (34% Europa, 26% Asia, usw.) durch normalize=True
df["continent"].value_counts(normalize=True)
# Out:
# europe     0.344334
# asia       0.268110
# america    0.179169
# africa     0.169858
# oceania    0.033608
# other      0.004844
# newcont    0.000076
# Name: continent, dtype: float64

# %%
df["land"].value_counts()
# Out:
# China                    118
# Czechia                  118
# Australia                118
# Russia                   118
# Iran                     118
#                         ...
# South_Sudan               21
# Sao_Tome_and_Principe     18
# Yemen                     17
# Western_Sahara             1
# NewLand                    1
# Name: land, Length: 208, dtype: int64

# %%
# Gruppierung nach Spalte Land
land_grp = df.groupby(["land"])
land_grp

# %%
# Zugriff auf die Gruppierung und Auswahl eines Landes
land_grp.get_group("Austria")
# Out:
#         land    daterep  day  month  year  cases  deaths  popdata2018  \
# 740  Austria 2020-04-26   26      4  2020     66      23    8847037.0
# 759  Austria 2020-04-25   25      4  2020     83       5    8847037.0
# 738  Austria 2020-04-24   24      4  2020     61      14    8847037.0
# 743  Austria 2020-04-23   23      4  2020     91      31    8847037.0
# 736  Austria 2020-04-22   22      4  2020     50       1    8847037.0
# ..       ...        ...  ...    ...   ...    ...     ...          ...
# 840  Austria 2020-01-04    4      1  2020      0       0    8847037.0
# 839  Austria 2020-01-03    3      1  2020      0       0    8847037.0
# 838  Austria 2020-01-02    2      1  2020      0       0    8847037.0
# 843  Austria 2020-01-01    1      1  2020      0       0    8847037.0
# 822  Austria 2019-12-31   31     12  2019      0       0    8847037.0
#
#     continent countriesAndTerritories fullgeo
# 740    europe              Österreich   atAUT
# 759    europe              Österreich   atAUT
# 738    europe              Österreich   atAUT
# 743    europe              Österreich   atAUT
# 736    europe              Österreich   atAUT
# ..        ...                     ...     ...
# 840    europe              Österreich   atAUT
# 839    europe              Österreich   atAUT
# 838    europe              Österreich   atAUT
# 843    europe              Österreich   atAUT
# 822    europe              Österreich   atAUT
#
# [118 rows x 11 columns]

# %%
# gleiches Ergebnis auch durch einen Filter erreichbar
filt = df["land"] == "Austria"
df.loc[filt]
# Out:
#         land    daterep  day  month  year  cases  deaths  popdata2018  \
# 740  Austria 2020-04-26   26      4  2020     66      23    8847037.0
# 759  Austria 2020-04-25   25      4  2020     83       5    8847037.0
# 738  Austria 2020-04-24   24      4  2020     61      14    8847037.0
# 743  Austria 2020-04-23   23      4  2020     91      31    8847037.0
# 736  Austria 2020-04-22   22      4  2020     50       1    8847037.0
# ..       ...        ...  ...    ...   ...    ...     ...          ...
# 840  Austria 2020-01-04    4      1  2020      0       0    8847037.0
# 839  Austria 2020-01-03    3      1  2020      0       0    8847037.0
# 838  Austria 2020-01-02    2      1  2020      0       0    8847037.0
# 843  Austria 2020-01-01    1      1  2020      0       0    8847037.0
# 822  Austria 2019-12-31   31     12  2019      0       0    8847037.0
#
#     continent countriesAndTerritories fullgeo
# 740    europe              Österreich   atAUT
# 759    europe              Österreich   atAUT
# 738    europe              Österreich   atAUT
# 743    europe              Österreich   atAUT
# 736    europe              Österreich   atAUT
# ..        ...                     ...     ...
# 840    europe              Österreich   atAUT
# 839    europe              Österreich   atAUT
# 838    europe              Österreich   atAUT
# 843    europe              Österreich   atAUT
# 822    europe              Österreich   atAUT
#
# [118 rows x 11 columns]

# %%
# Ausgabe der maximalen deaths nur für Österreich
filt = df["land"] == "Austria"
df.loc[filt]["deaths"].value_counts()
# Out:
# 0     79
# 18     7
# 1      3
# 2      3
# 16     3
# 9      3
# 10     2
# 23     2
# 22     2
# 5      2
# 12     2
# 4      1
# 8      1
# 31     1
# 13     1
# 30     1
# 17     1
# 20     1
# 21     1
# 24     1
# 14     1
# Name: deaths, dtype: int64

# %%
# Gruppierung nach land und Auswertung dieser Gruppierung nach der Spalte deaths mit value_counts
land_grp["deaths"].value_counts().head(50)
# Out:
# land                 deaths
# Afghanistan          0         85
#                      1          9
#                      2          5
#                      3          4
#                      4          4
# Albania              0         30
#                      1         13
#                      2          4
#                      3          2
# Algeria              0         71
#                      1          6
#                      2          5
#                      3          3
#                      4          3
#                      5          3
#                      8          3
#                      12         3
#                      9          2
#                      20         2
#                      21         2
#                      10         1
#                      11         1
#                      14         1
#                      16         1
#                      18         1
#                      19         1
#                      22         1
#                      25         1
#                      30         1
#                      42         1
# Andorra              0         21
#                      1         11
#                      2          8
#                      3          3
#                      4          1
# Angola               0         35
#                      2          1
# Anguilla             0         31
# Antigua_and_Barbuda  0         36
#                      1          1
#                      2          1
# Argentina            0         15
#                      7          6
#                      1          5
#                      2          5
#                      3          5
#                      6          4
#                      4          3
#                      5          2
#                      8          2
# Name: deaths, dtype: int64

# %%
# Ausgabe des Wertes für drei Ländern
land_grp["deaths"].value_counts().loc[["Austria","Germany","Switzerland"]]
# Out:
# land         deaths
# Austria      0         79
#              18         7
#              1          3
#              2          3
#              9          3
#              16         3
#              5          2
#              10         2
#              12         2
#              22         2
#              23         2
#              4          1
#              8          1
#              13         1
#              14         1
#              17         1
#              20         1
#              21         1
#              24         1
#              30         1
#              31         1
# Germany      0         74
#              2          3
#              1          2
#              140        2
#              184        2
#              3          1
#              4          1
#              22         1
#              23         1
#              27         1
#              30         1
#              32         1
#              49         1
#              55         1
#              64         1
#              66         1
#              72         1
#              92         1
#              110        1
#              126        1
#              128        1
#              129        1
#              141        1
#              145        1
#              149        1
#              170        1
#              171        1
#              173        1
#              179        1
#              194        1
#              215        1
#              227        1
#              242        1
#              246        1
#              254        1
#              266        1
#              281        1
#              285        1
#              299        1
#              315        1
# Switzerland  0         71
#              1          5
#              2          2
#              4          2
#              5          2
#              20         2
#              38         2
#              42         2
#              51         2
#              52         2
#              3          1
#              6          1
#              7          1
#              10         1
#              12         1
#              13         1
#              17         1
#              19         1
#              22         1
#              24         1
#              25         1
#              26         1
#              27         1
#              30         1
#              36         1
#              41         1
#              43         1
#              45         1
#              49         1
#              54         1
#              56         1
#              57         1
#              58         1
#              64         1
#              73         1
#              78         1
# Name: deaths, dtype: int64

# %%
# Gruppierung nach Ländern mit Ausgabe von Median pro Land
land_grp["cases"].median()
# Out:
# land
# Afghanistan        0.0
# Albania           13.0
# Algeria            0.0
# Andorra           14.0
# Angola             0.0
#                   ...
# Vietnam            0.0
# Western_Sahara     6.0
# Yemen              0.0
# Zambia             1.0
# Zimbabwe           0.0
# Name: cases, Length: 208, dtype: float64

# %%
# Gruppierung nach Ländern mit Ausgabe von Median mit Einschränkung auf 3 Länder
land_grp["cases"].median().loc[["Austria","Germany","Switzerland"]]
# Out:
# land
# Austria        2.0
# Germany        7.0
# Switzerland    0.5
# Name: cases, dtype: float64

# %%
# Gruppierung nach mehreren Statistiken und Einschränkung auf Ländern
land_grp["cases"].agg(["median","mean"]).loc[["Austria","Germany","Switzerland"]]
# Out:
#              median         mean
# land
# Austria         2.0   128.254237
# Germany         7.0  1306.567797
# Switzerland     0.5   244.161017

# %%
# Zuerste Filterung aller 0-Werte und dann Gruppierung nach Land und Ausgabe nach median()
non_zero_df = df[df["cases"]!=0]
land_grp = non_zero_df.groupby(["land"])
land_grp.median()
# Out:
#                  day  month  cases  deaths  popdata2018
# land
# Afghanistan     17.0    4.0   33.0     1.0   37172386.0
# Albania         16.5    4.0   13.5     0.0    2866376.0
# Algeria         17.0    4.0   65.0     4.0   42228429.0
# Andorra         17.0    4.0   16.0     1.0      77006.0
# Angola          14.0    4.0    2.0     0.0   30809762.0
# ...              ...    ...    ...     ...          ...
# Vietnam         13.0    3.0    4.0     0.0   95540395.0
# Western_Sahara  26.0    4.0    6.0     0.0          NaN
# Yemen           10.0    4.0    1.0     0.0   28498687.0
# Zambia          21.0    4.0    3.0     0.0   17351822.0
# Zimbabwe        19.0    4.0    1.0     0.0   14439018.0
#
# [207 rows x 5 columns]

# %%
# Test-Dateframe mit None-Lücken
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
# Löschen aller Zeilen bei denen Elemente fehlen
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# Gleiches Ergebnis mit den Defaultwerten
# Mit Index ist ein Löschen von Zeilen möglich - mit Column wäre ein Löschen von Spalten möglich
# Any gibt an nach welchen Kriterien gelöscht werden soll - in diesem Fall alle Zeilen wo etwas fehlt
df.dropna(axis = "index", how = "any")
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# durch how=all werden nur mehr die Zeilen gelöscht bei denen alle Werte nicht vorhanden sind - Rest bleibt bestehen
df.dropna(axis = "index", how = "all")

# %%
# Es erfolgt keine Löschung, weil es keine Spalte gibt bei der alle Elemente fehlen
df.dropna(axis = "columns", how = "all")

# %%
# Ergibt leeres Dataframe, in jeder Spalte gibt es mind. ein Element welche leer ist
df.dropna(axis = "columns", how = "any")

# %%
# Check erfolgt nur für eine Spalte email
df.dropna(axis = "index", how = "any", subset=["email"])

# %%
# Missing und NA wird durch Numpy-NAN ersetzt
df = pd.DataFrame(people)
df.replace("NA",np.nan, inplace=True)
df.replace("Missing",np.nan, inplace=True)
df

# %%
# Check wo es im Dataframe leere Values gibt
df.isna()

# %%
# Ersetzt alle NaN bzw. None-Inhalte durch den angegebenen Wert
# bleibt erst permanent gespeichert mit dem Befehel inplace=True
df.fillna("MISSING")

# %%
# Ersetzt die leeren Werte NaN bzw. None mit 0
df.fillna(0)

# %%
# Age ist in diesem Fall auch ein String bzw. Object
df.dtypes

# %%
# Bildung des Mean nicht möglich, weil es sich um age um einen String handelt
df["age"].mean()

# %%
# bei nan handelt es sich im Hintergrund um einen Float - daher ist eine Umwandlung von float zu int nicht möglich
type(np.nan)
# Out:
# float

# %%
Umwandlung bei den nan-Einträgen nicht möglich - untenstehende Fehlermeldung wird ausgegeben
df["age"] = df["age"].astype(int)

# %%
# Umwandlung der Spalte age zu float
df["age"] = df["age"].astype(float)
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
# Weiterbearbeitung z.b. Durchschnittsbildung jetzt möglich
df["age"].mean()
# Out:
# 46.75

# %%
# CSV-File einlesen
df =  pd.read_csv("ETH_1h.csv")
df.head(5)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# Date steht als String zur Verfügung und nicht als DateTime
# Aufbau des Datums hat auch ein Sonderformat
# Daher muss das Format genau vorgegeben werden
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d %I-%p")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  datetime64[ns]
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.3+ MB

# %%
# Ausgabe des Wochentages für ein bestimmtes Datetime-Element
df.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
# Datetime-Umwandlung kann aber auc direkt beim CSV-Einlesen gemacht werden
# Umwandlung erfolgt hier mittels strptime()
d_parser =  lambda x: pd.datetime.strptime(x, "%Y-%m-%d %I-%p")
df =  pd.read_csv("ETH_1h.csv", parse_dates=["Date"], date_parser=d_parser)
# Out:
# c:\users\polzi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Umwandlung der gesamten DateTimeSpalte auf den Wochentag pro Datum
df["Date"].dt.day_name()

# %%
# Zusätzliche Spalte wird eingefügt mit dem Wochentag pro Zeile
df["DayOfWeek"] = df["Date"].dt.day_name()
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# 0        Friday
# 1        Friday
# 2        Friday
# 3        Friday
# 4        Friday
# ...         ...
# 23669  Saturday
# 23670  Saturday
# 23671  Saturday
# 23672  Saturday
# 23673  Saturday
#
# [23674 rows x 8 columns]

# %%
# Ältestes Datum wird ausgegeben
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
# Neuestes Datum wird ausgegeben
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
# Zeitdifferenz von 2 Datumswerten kann ermittelt werden
df["Date"].max() - df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# Es werden nur Sätze ausgegeben, die aus dem Jahr 2020 sind
filt=(df["Date"] >= "2020")
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# 1        Friday
# 2        Friday
# 3        Friday
# 4        Friday
# ...         ...
# 1744  Wednesday
# 1745  Wednesday
# 1746  Wednesday
# 1747  Wednesday
# 1748  Wednesday
#
# [1749 rows x 8 columns]

# %%
# Ausgabe von Sätzen aus 2019
filt=(df["Date"] >= "2019") & (df["Date"] < "2020")
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# 1749    Tuesday
# 1750    Tuesday
# 1751    Tuesday
# 1752    Tuesday
# 1753    Tuesday
# ...         ...
# 10504   Tuesday
# 10505   Tuesday
# 10506   Tuesday
# 10507   Tuesday
# 10508   Tuesday
#
# [8760 rows x 8 columns]

# %%
# Ausgabe von Sätzen aus 2019 ab 30.6.2019
filt=(df["Date"] >= pd.to_datetime("2019-06-30")) & (df["Date"] < pd.to_datetime("2020-01-01"))
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 1749 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                  ...     ...     ...     ...     ...     ...         ...
# 6184 2019-06-30 04:00:00  ETHUSD  318.24  319.45  316.99  318.25   854276.00
# 6185 2019-06-30 03:00:00  ETHUSD  319.03  320.44  316.70  318.24  1055287.09
# 6186 2019-06-30 02:00:00  ETHUSD  320.96  321.26  318.45  319.03  1245017.78
# 6187 2019-06-30 01:00:00  ETHUSD  322.65  322.97  318.06  320.96  1656673.96
# 6188 2019-06-30 00:00:00  ETHUSD  317.00  323.61  316.96  322.65  3612116.61
#
#      DayOfWeek
# 1749   Tuesday
# 1750   Tuesday
# 1751   Tuesday
# 1752   Tuesday
# 1753   Tuesday
# ...        ...
# 6184    Sunday
# 6185    Sunday
# 6186    Sunday
# 6187    Sunday
# 6188    Sunday
#
# [4440 rows x 8 columns]

# %%
# Date als Index festlegen
df.set_index("Date", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-3440ee64d057> in <module>
#       1 # Date als Index festlegen
# ----> 2 df.set_index("Date", inplace=True)
#
# c:\users\polzi\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
# Wenn die Datetime-Spalte ein Index ist, dann ist auch eine direkt Suche nach 2019 möglich
df["2019"]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# 2019-12-31 22:00:00   Tuesday
# 2019-12-31 21:00:00   Tuesday
# 2019-12-31 20:00:00   Tuesday
# 2019-12-31 19:00:00   Tuesday
# ...                       ...
# 2019-01-01 04:00:00   Tuesday
# 2019-01-01 03:00:00   Tuesday
# 2019-01-01 02:00:00   Tuesday
# 2019-01-01 01:00:00   Tuesday
# 2019-01-01 00:00:00   Tuesday
#
# [8760 rows x 7 columns]

# %%
# Wenn die Datetime-Spalte ein Index ist, dann kann die Abfrage auch mit Slices erfolgen
df["2020-01":"2020-02"]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# 2020-02-29 22:00:00   Saturday
# 2020-02-29 21:00:00   Saturday
# 2020-02-29 20:00:00   Saturday
# 2020-02-29 19:00:00   Saturday
# ...                        ...
# 2020-01-01 04:00:00  Wednesday
# 2020-01-01 03:00:00  Wednesday
# 2020-01-01 02:00:00  Wednesday
# 2020-01-01 01:00:00  Wednesday
# 2020-01-01 00:00:00  Wednesday
#
# [1440 rows x 7 columns]

# %%
# Durchschnittspreis für diesen Zeitraum
df["2020-01":"2020-02"]["Close"].mean()
# Out:
# 195.1655902777778

# %%
# Maximaler Höchststand pro Tag des Kurse
df["2020-01-01"]["High"].max()
# Out:
# 132.68

# %%
# Höchststand von jedem Tag wird ausgegeben
df["High"].resample("D").max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# Andere Variante um den Höchstsstand eines Tages zu ermitteln
highs = df["High"].resample("D").max()
highs["2020-01-01"]
# Out:
# 132.68

# %%
# matplotlib verwenden
# %matplotlib inline

# %%
# Ausgabe der Höchststand pro Tag mittels matplotlib
highs.plot()

# %%
# Using multiple columns resampling - komplettes Dataframe ändern
# Gibt den Durchschnittswert auf wöchentlicher Basis für alle Werte aus
df.resample("W").mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
# mit der Agg-Funktion kann pro Spalte festgelegt werden, welche Funktion mean/max/min/sum angewandt wird
df.resample("W").agg({"Close":"mean","High":"max","Low":"min","Volume":"sum"})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
